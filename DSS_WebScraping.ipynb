# %%
import urllib3
import certifi
from bs4 import BeautifulSoup, element
import re
import openpyxl
import pickle
import json
import geopy
import requests
import pandas as pd
import numpy as np

# a few handy url generator funcitons
base_url = lambda start_num=1: "https://www.dss.virginia.gov/facility/search/alf.cgi?rm=Search;;Start={start_num}".format(start_num=start_num)
loc_url = lambda loc_id: "https://www.dss.virginia.gov/facility/search/alf.cgi?rm=Details;ID={loc_id}".format(loc_id=loc_id)
insp_url = lambda inspection_id, loc_id: "https://www.dss.virginia.gov/facility/search/alf.cgi?rm=Inspection;Inspection={inspection_id};ID={loc_id}".format(inspection_id=inspection_id, loc_id=loc_id)

http = urllib3.PoolManager(
    cert_reqs='CERT_REQUIRED',  # Force certificate check.
    ca_certs=certifi.where(),  # Path to the Certifi bundle.
)

# %%
### I couldn't get the google maps api to work. I created an api_key under my personal google account but it didn't seem to work
### I believe this was needed for some spatial analysis this project needed so not sure it's needed.

# Define geolocator from GooglemapsV3 api :: no key required :: output projection EPSG:3857 Spherical Mercator (Web Mercator)
#geolocator = geopy.geocoders.GoogleV3(api_key='AIzaSyDDWgZjAuas0i7U2BSpvGR8gn8KPMItLcE')
#domain='maps.googleapis.com', 

def get_page(url):
    '''Get all of our page data in a consistent fashion'''

    r = http.request('GET', url)
    # lxml is much better than stock python parser
    return BeautifulSoup(r.data, 'lxml')

# %%
def get_key(tag):
    '''a lot of time we will need to extract a key from a tag'''
    return tag.get_text().strip().strip(':').lower().replace(' ', '_').encode('ascii', 'ignore')

# %%
def get_loc_ids(start_num=1):
    '''Location id Generator function.
    This will automatically handeling paging of main id lookup, but you can skip ahead by passing in a number representing the ids place in global list, 1 based index'''

    done = False
    while not done:
        print ('Fetching some location ids')
        soup = get_page(base_url(start_num))

        num_locs = int(re.search('\t(\d{1,9}) records', soup.find_all('table')[1].find_all('td')[1].text).group(1))

        ids = ([int(re.search(';ID=(\d{1,9});', a['href']).group(1)) for a in soup.find_all('table')[3].find_all('a')])

        for loc_id in ids:
            start_num += 1
            yield loc_id

        if start_num >= num_locs:
        #if start_num >= 400: #Used to break into chunks
            done = True

# %%
encoding = 'utf-8'
def parse_loc(loc_id):
    '''Fetch detailed info for a single location based on id'''

    print("Fetching info for location id =", loc_id)
    
    soup = get_page(loc_url(loc_id))

    location_info = {
        '_type': 'location_info',
        'id': loc_id
    }

    # big breakdowns go by tables
    basic_info, additional_info, inspection_info = soup.find_all('table')[:3]

    # first table has a bunch of data in fairly unstructured format
    name_and_address, city_zip, phone_number = basic_info.find_all('tr')

    location_info.update({
        'phone_number': phone_number.get_text().strip()
    })

    parsed_name_address = [line.strip() for line in name_and_address.get_text().split('\n') if line.strip()]
    location_info.update({
        'name': parsed_name_address[0],
        'address' : parsed_name_address[1],
        'city_zip' : city_zip.get_text().strip()
    })
    
### Commented out Google API geolocator since API key didn't seem to work    
    # Get address for geolocator with city, state and without \n
    #gcode_address = city_zip.get_text().strip()#' '.join([' '.join(parsed_name_address[1:]), city_zip.get_text().strip()])

### Address needs to have name stripped from it.    
    #location_info.update({'address': name_and_address.get_text().strip()})

    # there are a lot of additional info that follows the general format of <td>key</td><td>value</td>
    # but some need some extra parsing
    extra_parsing = {
        'administrator': lambda administrator: administrator.replace('\t', '').replace('\n', ''),
        'inspector': lambda inspector_info: [line.strip() for line in inspector_info.split('\n') if line.strip()],
        'business_hours': lambda business_hours: business_hours.replace('\t', '').replace('\n', ''),
        'capacity' : lambda capacity: capacity.replace('\t', '').replace('\n', ''),
        'expiration_date': lambda expiration_date: expiration_date.replace('\t', '').replace('\n', ''),
        'facility_type': lambda facility_type: facility_type.replace('\t', '').replace('\n', ''),
        'license_type' : lambda license_type: license_type.replace('\t', '').replace('\n', ''),
        'qualification': lambda qualification: qualification.replace('\t', '').replace('\n', '')
    }
    for row in additional_info.find_all('tr')[:-1]:
        key = get_key(row.find_all('td')[0])
        key = str(key, encoding)
        val = row.find_all('td')[1].get_text().strip()
        if key in extra_parsing:
            val = extra_parsing[key](val)
        #val = val.replace('\t', '').replace('\n', '').replace(':', '')
        location_info.update({key: val})

    if 'inspector' in location_info:
        location_info.update({
            'inspector_name': location_info['inspector'][0],
            'inspector_phone': location_info['inspector'][1]
        })
        del location_info['inspector']

    if inspection_info.table:
        inspection_ids = [int(re.search(';Inspection=(\d{1,6});', tag.a['href']).group(1)) for tag in inspection_info.table.find_all('tr')[1:]]
        location_info['inspections'] = [parse_inspection(insp_id, loc_id) for insp_id in inspection_ids]

    else:
        location_info['inspections'] = []

    return location_info

# %%
def parse_inspection(insp_id, loc_id):
    '''To get inspection data, you need to give the site both the inspection id and location id'''

    print (" Fetching info for inspection id =", insp_id)

    soup = get_page(insp_url(insp_id, loc_id))

    inspection_info = {
        '_type': 'inspection_info',
        'id': insp_id,
        'loc_id': loc_id
    }

    # there is some redundant info about location, then some relevant stuff
    date, complaint = soup.find('div', id='main_content').find_all('p')[3:5]
    inspection_info.update({
        'date': date.get_text().split('\n')[5].strip(),
        'complaint': complaint.get_text().split('\n')[3].strip()
    })
    
    parsers = {
    'areas_reviewed': lambda areas_reviewed: areas_reviewed.get_text().strip(),
    'technical_assistance': lambda technical_assistance: technical_assistance.get_text().strip(),
    'comments': lambda comments: comments.get_text().strip().replace('\r', '\n'),
    'violations': parse_violations
    }
    
    table_ids = [get_key(tag) for tag in soup.find_all('dt')]
    for key, tag in zip(table_ids, soup.find_all('table')[:len(table_ids)]):
        key = str(key, encoding)
        inspection_info[key] = parsers[key](tag)
       
 
    return inspection_info

# %%
# we will need a lot of specialized parsers
encoding = 'utf-8'
def parse_violations(violations):

    parsers = {
        'standard_#': lambda val: val.strip(),
        'description': lambda val: val.strip().replace('\r', '\n'),
        'complaint_related': lambda val: val.strip(),
        'plan_of_correction': lambda val: val.strip().replace('\r', '\n')
    }
    line_num = 0
    violation_lines = violations.find_all('tr')
    maxline = len(violation_lines) - 1
    violations_info = []
    violation_info = {}

    while line_num < len(violation_lines):

        if violation_lines[line_num].td is None:
            # there seems to be blank lines after 'complain_related' that don't have <td>s
            pass

        #elif violation_lines[line_num].hr is None:
        #    pass

        elif violation_lines[line_num].hr:
            violations_info.append(violation_info)
            violation_info = {}

        elif line_num == maxline:
            violations_info.append(violation_info)

        else:
            encoding = 'utf-8'
            raw_key, val = violation_lines[line_num].get_text().split(':', 1)
            key = raw_key.strip().strip(':').lower().replace(' ', '_').encode('ascii', 'ignore')
            key = str(key, encoding)
            violation_info[key] = parsers[key](val)

        line_num += 1

    return violations_info

# %%
## Get all location IDs
ids = list(get_loc_ids())
#df_ids = pd.DataFrame(ids,columns=["LocationIDs"])
# Out:
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids
# Fetching some location ids

# %%
## Testing top N location IDs to view data
#top_n_idx = np.argsort(ids)[-10:]
#top_n_values = [ids[i] for i in top_n_idx]
#top_n_values

# %%
#del loc ## Delete loc dataframe since next step appends rows every time it is run

## Create dataframe to append data to
loc = pd.DataFrame()

# %%
loc_id = ids ## All facilities
    #top_n_values ## Sample of facilities 
for i in loc_id:
    loc = loc.append(parse_loc(i), ignore_index = True)
# Out:
# Fetching info for location id = 44307
#  Fetching info for inspection id = 30760
#  Fetching info for inspection id = 29987
#  Fetching info for inspection id = 29663
#  Fetching info for inspection id = 28727
#  Fetching info for inspection id = 27040
#  Fetching info for inspection id = 26142
#  Fetching info for inspection id = 25939
#  Fetching info for inspection id = 25492
#  Fetching info for inspection id = 25094
#  Fetching info for inspection id = 24977
#  Fetching info for inspection id = 24801
# Fetching info for location id = 35625
#  Fetching info for inspection id = 30734
#  Fetching info for inspection id = 29600
#  Fetching info for inspection id = 29367
#  Fetching info for inspection id = 28181
#  Fetching info for inspection id = 26841
#  Fetching info for inspection id = 25267
# Fetching info for location id = 46962
#  Fetching info for inspection id = 29790
#  Fetching info for inspection id = 29456
#  Fetching info for inspection id = 29154
# Fetching info for location id = 32972
#  Fetching info for inspection id = 30479
#  Fetching info for inspection id = 30034
#  Fetching info for inspection id = 29922
#  Fetching info for inspection id = 29719
#  Fetching info for inspection id = 29720
#  Fetching info for inspection id = 29562
#  Fetching info for inspection id = 29357
#  Fetching info for inspection id = 29220
#  Fetching info for inspection id = 28525
#  Fetching info for inspection id = 28447
#  Fetching info for inspection id = 28193
#  Fetching info for inspection id = 27940
#  Fetching info for inspection id = 27903
#  Fetching info for inspection id = 26570
#  Fetching info for inspection id = 25118
# Fetching info for location id = 46842
#  Fetching info for inspection id = 29745
#  Fetching info for inspection id = 28718
#  Fetching info for inspection id = 30433
#  Fetching info for inspection id = 29703
#  Fetching info for inspection id = 29412
#  Fetching info for inspection id = 29013
# Fetching info for location id = 41872
#  Fetching info for inspection id = 30533
#  Fetching info for inspection id = 29055
#  Fetching info for inspection id = 26739
#  Fetching info for inspection id = 28095
#  Fetching info for inspection id = 25042
# Fetching info for location id = 8912
#  Fetching info for inspection id = 30161
#  Fetching info for inspection id = 28778
#  Fetching info for inspection id = 27624
#  Fetching info for inspection id = 26569
#  Fetching info for inspection id = 24734
# Fetching info for location id = 8743
#  Fetching info for inspection id = 30728
#  Fetching info for inspection id = 30658
#  Fetching info for inspection id = 30517
#  Fetching info for inspection id = 29453
#  Fetching info for inspection id = 27549
#  Fetching info for inspection id = 26063
#  Fetching info for inspection id = 24850
#  Fetching info for inspection id = 24356
#  Fetching info for inspection id = 24250
# Fetching info for location id = 44453
#  Fetching info for inspection id = 28411
#  Fetching info for inspection id = 28273
#  Fetching info for inspection id = 27407
#  Fetching info for inspection id = 27205
#  Fetching info for inspection id = 26597
#  Fetching info for inspection id = 26058
#  Fetching info for inspection id = 25866
#  Fetching info for inspection id = 25557
#  Fetching info for inspection id = 25175
# Fetching info for location id = 35321
#  Fetching info for inspection id = 30589
#  Fetching info for inspection id = 30343
#  Fetching info for inspection id = 29960
#  Fetching info for inspection id = 29723
#  Fetching info for inspection id = 29610
#  Fetching info for inspection id = 29558
#  Fetching info for inspection id = 29310
#  Fetching info for inspection id = 29309
#  Fetching info for inspection id = 28474
#  Fetching info for inspection id = 28586
#  Fetching info for inspection id = 27950
#  Fetching info for inspection id = 27919
#  Fetching info for inspection id = 27920
#  Fetching info for inspection id = 26143
#  Fetching info for inspection id = 25883
#  Fetching info for inspection id = 25618
#  Fetching info for inspection id = 25292
# Fetching info for location id = 30140
#  Fetching info for inspection id = 30031
#  Fetching info for inspection id = 29029
#  Fetching info for inspection id = 26955
#  Fetching info for inspection id = 26847
#  Fetching info for inspection id = 25565
#  Fetching info for inspection id = 24797
# Fetching info for location id = 47772
#  Fetching info for inspection id = 30327
# Fetching info for location id = 47162
#  Fetching info for inspection id = 30314
#  Fetching info for inspection id = 29556
# Fetching info for location id = 47763
#  Fetching info for inspection id = 30361
# Fetching info for location id = 47764
#  Fetching info for inspection id = 30339
# Fetching info for location id = 39768
#  Fetching info for inspection id = 30317
#  Fetching info for inspection id = 29436
#  Fetching info for inspection id = 28224
#  Fetching info for inspection id = 26199
#  Fetching info for inspection id = 25241
#  Fetching info for inspection id = 24682
# Fetching info for location id = 47773
#  Fetching info for inspection id = 30328
# Fetching info for location id = 47769
#  Fetching info for inspection id = 30306
# Fetching info for location id = 47767
#  Fetching info for inspection id = 30391
# Fetching info for location id = 47765
#  Fetching info for inspection id = 30292
# Fetching info for location id = 33136
#  Fetching info for inspection id = 28164
#  Fetching info for inspection id = 28163
#  Fetching info for inspection id = 30795
#  Fetching info for inspection id = 29757
#  Fetching info for inspection id = 29269
#  Fetching info for inspection id = 28160
#  Fetching info for inspection id = 27341
#  Fetching info for inspection id = 26412
#  Fetching info for inspection id = 25873
#  Fetching info for inspection id = 26477
#  Fetching info for inspection id = 25696
#  Fetching info for inspection id = 25695
#  Fetching info for inspection id = 25872
#  Fetching info for inspection id = 24996
#  Fetching info for inspection id = 24104
# Fetching info for location id = 47760
#  Fetching info for inspection id = 30304
# Fetching info for location id = 37551
#  Fetching info for inspection id = 30348
#  Fetching info for inspection id = 30181
#  Fetching info for inspection id = 30170
#  Fetching info for inspection id = 29992
#  Fetching info for inspection id = 29977
#  Fetching info for inspection id = 29482
#  Fetching info for inspection id = 29255
#  Fetching info for inspection id = 29025
#  Fetching info for inspection id = 27773
#  Fetching info for inspection id = 26404
#  Fetching info for inspection id = 24955
#  Fetching info for inspection id = 26984
#  Fetching info for inspection id = 26608
#  Fetching info for inspection id = 25641
#  Fetching info for inspection id = 25174
#  Fetching info for inspection id = 24978
#  Fetching info for inspection id = 24666
# Fetching info for location id = 47625
#  Fetching info for inspection id = 30585
#  Fetching info for inspection id = 30188
# Fetching info for location id = 40192
#  Fetching info for inspection id = 29621
#  Fetching info for inspection id = 28368
#  Fetching info for inspection id = 28347
#  Fetching info for inspection id = 27000
#  Fetching info for inspection id = 25415
#  Fetching info for inspection id = 24092
# Fetching info for location id = 44783
#  Fetching info for inspection id = 30290
#  Fetching info for inspection id = 28898
#  Fetching info for inspection id = 28412
#  Fetching info for inspection id = 27737
#  Fetching info for inspection id = 27489
#  Fetching info for inspection id = 26890
#  Fetching info for inspection id = 26729
#  Fetching info for inspection id = 26295
#  Fetching info for inspection id = 26125
#  Fetching info for inspection id = 25642
# Fetching info for location id = 18798
#  Fetching info for inspection id = 30437
#  Fetching info for inspection id = 28644
#  Fetching info for inspection id = 28489
#  Fetching info for inspection id = 27810
#  Fetching info for inspection id = 27332
#  Fetching info for inspection id = 26630
#  Fetching info for inspection id = 26229
#  Fetching info for inspection id = 24157
# Fetching info for location id = 42579
#  Fetching info for inspection id = 28971
#  Fetching info for inspection id = 28281
#  Fetching info for inspection id = 25776
#  Fetching info for inspection id = 25416
#  Fetching info for inspection id = 24467
#  Fetching info for inspection id = 24370
#  Fetching info for inspection id = 24095
# Fetching info for location id = 46879
#  Fetching info for inspection id = 29640
#  Fetching info for inspection id = 29418
#  Fetching info for inspection id = 28825
# Fetching info for location id = 47667
#  Fetching info for inspection id = 30273
# Fetching info for location id = 45275
#  Fetching info for inspection id = 30727
#  Fetching info for inspection id = 30219
#  Fetching info for inspection id = 30221
#  Fetching info for inspection id = 29932
#  Fetching info for inspection id = 28694
#  Fetching info for inspection id = 27497
#  Fetching info for inspection id = 27343
#  Fetching info for inspection id = 27318
#  Fetching info for inspection id = 26867
# Fetching info for location id = 33160
#  Fetching info for inspection id = 29852
#  Fetching info for inspection id = 28702
#  Fetching info for inspection id = 27571
#  Fetching info for inspection id = 27279
#  Fetching info for inspection id = 25806
#  Fetching info for inspection id = 25784
#  Fetching info for inspection id = 24380
#  Fetching info for inspection id = 24381
#  Fetching info for inspection id = 24051
# Fetching info for location id = 38966
#  Fetching info for inspection id = 30791
#  Fetching info for inspection id = 29770
#  Fetching info for inspection id = 28577
#  Fetching info for inspection id = 27786
#  Fetching info for inspection id = 27482
#  Fetching info for inspection id = 27410
#  Fetching info for inspection id = 27372
#  Fetching info for inspection id = 25786
#  Fetching info for inspection id = 24475
# Fetching info for location id = 10709
#  Fetching info for inspection id = 30385
#  Fetching info for inspection id = 30384
#  Fetching info for inspection id = 30046
#  Fetching info for inspection id = 28680
#  Fetching info for inspection id = 28268
#  Fetching info for inspection id = 27365
#  Fetching info for inspection id = 25819
#  Fetching info for inspection id = 24759
# Fetching info for location id = 38911
#  Fetching info for inspection id = 30075
#  Fetching info for inspection id = 29970
#  Fetching info for inspection id = 29946
#  Fetching info for inspection id = 27505
#  Fetching info for inspection id = 26899
#  Fetching info for inspection id = 26732
#  Fetching info for inspection id = 26669
#  Fetching info for inspection id = 26053
# Fetching info for location id = 44027
#  Fetching info for inspection id = 30449
#  Fetching info for inspection id = 30474
#  Fetching info for inspection id = 30275
# ...
#  Fetching info for inspection id = 30338
#  Fetching info for inspection id = 30078
#  Fetching info for inspection id = 29727
# Fetching info for location id = 9401
#  Fetching info for inspection id = 30510
#  Fetching info for inspection id = 28830
#  Fetching info for inspection id = 27779
#  Fetching info for inspection id = 26664
#  Fetching info for inspection id = 24479
#  Fetching info for inspection id = 24210
# Fetching info for location id = 46293
#  Fetching info for inspection id = 30462
#  Fetching info for inspection id = 30179
#  Fetching info for inspection id = 29753
#  Fetching info for inspection id = 28981
#  Fetching info for inspection id = 28796
#  Fetching info for inspection id = 28409
# Fetching info for location id = 15791
#  Fetching info for inspection id = 30690
#  Fetching info for inspection id = 30714
#  Fetching info for inspection id = 30171
#  Fetching info for inspection id = 29781
#  Fetching info for inspection id = 29779
#  Fetching info for inspection id = 29602
#  Fetching info for inspection id = 29655
#  Fetching info for inspection id = 29290
#  Fetching info for inspection id = 28507
#  Fetching info for inspection id = 28482
#  Fetching info for inspection id = 28243
#  Fetching info for inspection id = 28242
#  Fetching info for inspection id = 28135
#  Fetching info for inspection id = 27398
#  Fetching info for inspection id = 27390
#  Fetching info for inspection id = 27630
#  Fetching info for inspection id = 26949
#  Fetching info for inspection id = 26818
#  Fetching info for inspection id = 26443
#  Fetching info for inspection id = 25238
#  Fetching info for inspection id = 25098
#  Fetching info for inspection id = 24134
# Fetching info for location id = 32282
#  Fetching info for inspection id = 30527
#  Fetching info for inspection id = 29207
#  Fetching info for inspection id = 28074
#  Fetching info for inspection id = 27163
#  Fetching info for inspection id = 26590
#  Fetching info for inspection id = 25410
#  Fetching info for inspection id = 25337
# Fetching info for location id = 38604
#  Fetching info for inspection id = 30428
#  Fetching info for inspection id = 29181
#  Fetching info for inspection id = 27837
#  Fetching info for inspection id = 26348
#  Fetching info for inspection id = 25244
#  Fetching info for inspection id = 24141
# Fetching info for location id = 42097
#  Fetching info for inspection id = 30152
#  Fetching info for inspection id = 29350
#  Fetching info for inspection id = 27688
#  Fetching info for inspection id = 27333
#  Fetching info for inspection id = 26249
#  Fetching info for inspection id = 24514
#  Fetching info for inspection id = 24112
# Fetching info for location id = 44321
#  Fetching info for inspection id = 30264
#  Fetching info for inspection id = 28480
#  Fetching info for inspection id = 27138
#  Fetching info for inspection id = 25647
#  Fetching info for inspection id = 25334
#  Fetching info for inspection id = 24937
#  Fetching info for inspection id = 24912
# Fetching info for location id = 45867
#  Fetching info for inspection id = 30404
#  Fetching info for inspection id = 29838
#  Fetching info for inspection id = 29271
#  Fetching info for inspection id = 28170
#  Fetching info for inspection id = 27922
#  Fetching info for inspection id = 27579
# Fetching info for location id = 10750
#  Fetching info for inspection id = 30112
#  Fetching info for inspection id = 28552
#  Fetching info for inspection id = 27755
#  Fetching info for inspection id = 27519
#  Fetching info for inspection id = 29859
#  Fetching info for inspection id = 29827
#  Fetching info for inspection id = 29709
#  Fetching info for inspection id = 29778
#  Fetching info for inspection id = 29711
#  Fetching info for inspection id = 29262
#  Fetching info for inspection id = 29087
#  Fetching info for inspection id = 29086
#  Fetching info for inspection id = 28766
#  Fetching info for inspection id = 28306
#  Fetching info for inspection id = 28043
#  Fetching info for inspection id = 27853
#  Fetching info for inspection id = 27327
# Fetching info for location id = 24389
#  Fetching info for inspection id = 30482
#  Fetching info for inspection id = 29058
#  Fetching info for inspection id = 27921
#  Fetching info for inspection id = 27382
#  Fetching info for inspection id = 27157
#  Fetching info for inspection id = 26381
#  Fetching info for inspection id = 25655
#  Fetching info for inspection id = 25034
#  Fetching info for inspection id = 24768
# Fetching info for location id = 40095
#  Fetching info for inspection id = 28551
#  Fetching info for inspection id = 30472
#  Fetching info for inspection id = 29791
#  Fetching info for inspection id = 28123
#  Fetching info for inspection id = 26421
#  Fetching info for inspection id = 25600
#  Fetching info for inspection id = 24151
# Fetching info for location id = 48075
#  Fetching info for inspection id = 30581

# %%
## rename id to loc_id for merging with inspection data
loc = loc.rename({"id":"loc_id"},axis=1)

# %%
loc
# Out:
#              _type                    address         administrator  \
# 0    location_info        1000 Twinridge Lane      Paige  Carpenter
# 1    location_info     524 Pisgah Church Road  Mr. Kristopher  Drew
# 2    location_info           5904 Pine Street   Adeloyin  Olokodama
# 3    location_info         50 Burkholder Lane    Ms Laura  Fasching
# 4    location_info         103 Lee Burke Road    Ms Theresa  Taplin
# ..             ...                        ...                   ...
# 170  location_info  5500 Williamsburg Landing     Ms. Vonnie  Adams
# 171  location_info            3365 Ogden Road       Cleopatra  Kitt
# 172  location_info         201 W. Criser Road          Jack  Norris
# 173  location_info         10046 Rinker Drive          Bill  Okyere
# 174  location_info   10192 Atlee Station Road          Bill  Okyere
#
#                                         business_hours capacity  \
# 0                            24 hours  - 24 hours, \r7      120
# 1                                                  NaN       11
# 2                                 7am  - 7am, \r7 days        7
# 3              24 hours a day  - 24 hours a day, \rAll       30
# 4    24 hour operation  - 24 hour operation, \rSund...       78
# ..                                                 ...      ...
# 170                                                NaN      120
# 171                                                NaN      130
# 172                                                NaN       67
# 173                                24 hours , \r7 days        8
# 174                               8am  - 8am, \r7 days        8
#
#                       city_zip expiration_date             facility_type  \
# 0          RICHMOND, VA  23235   Aug. 27, 2023  Assisted Living Facility
# 1              RICE, VA  23966   June 29, 2022  Assisted Living Facility
# 2           HENRICO, VA  23075    Nov. 2, 2022  Assisted Living Facility
# 3        NEW MARKET, VA  22844   Aug. 31, 2022  Assisted Living Facility
# 4       FRONT ROYAL, VA  22630   June 14, 2022  Assisted Living Facility
# ..                         ...             ...                       ...
# 170    WILLIAMSBURG, VA  23185  March 15, 2023  Assisted Living Facility
# 171         ROANOKE, VA  24018  April 10, 2023  Assisted Living Facility
# 172     FRONT ROYAL, VA  22630   April 2, 2023  Assisted Living Facility
# 173  MECHANICSVILLE, VA  23116   Nov. 20, 2023  Assisted Living Facility
# 174  MECHANICSVILLE, VA  23116   Oct. 11, 2022  Assisted Living Facility
#
#       loc_id                                        inspections  \
# 0    44307.0  [{'_type': 'inspection_info', 'id': 30760, 'lo...
# 1    35625.0  [{'_type': 'inspection_info', 'id': 30734, 'lo...
# 2    46962.0  [{'_type': 'inspection_info', 'id': 29790, 'lo...
# 3    32972.0  [{'_type': 'inspection_info', 'id': 30479, 'lo...
# 4    46842.0  [{'_type': 'inspection_info', 'id': 29745, 'lo...
# ..       ...                                                ...
# 170  21323.0  [{'_type': 'inspection_info', 'id': 30747, 'lo...
# 171  45762.0  [{'_type': 'inspection_info', 'id': 30427, 'lo...
# 172  24389.0  [{'_type': 'inspection_info', 'id': 30482, 'lo...
# 173  40095.0  [{'_type': 'inspection_info', 'id': 28551, 'lo...
# 174  48075.0  [{'_type': 'inspection_info', 'id': 30581, 'lo...
#
#         inspector_name inspector_phone license_type  \
# 0    Yvonne  Randolph:  (804) 662-7454     Two Year
# 1    Jennifer  Stokes:  (540) 589-5216     Two Year
# 2    Yvonne  Randolph:  (804) 662-7454     One Year
# 3    Rhonda L Whitmer:  (540) 292-5932     One Year
# 4    Rhonda L Whitmer:  (540) 292-5932     One Year
# ..                 ...             ...          ...
# 170    Willie  Barnes:  (757) 439-6815     One Year
# 171   Cynthia Jo Ball:  (540) 309-2968     One Year
# 172  Sharon  DeBoever:  (540) 292-5930     Two Year
# 173  Yvonne  Randolph:  (804) 662-7454   Three Year
# 174  Yvonne  Randolph:  (804) 662-7454  Conditional
#
#                                                   name    phone_number  \
# 0                                  Seaton Chesterfield  (804) 327-1990
# 1                                        Second Chance  (434) 392-9276
# 2                          Secure Assisted Living, LLC  (804) 882-6978
# 3                               Shenandoah Place, Inc.  (540) 740-4300
# 4                             Shenandoah Senior Living  (540) 635-7923
# ..                                                 ...             ...
# 170                  WoodHaven At Williamsburg Landing  (757) 253-0303
# 171  Woodland Hills Independent Living, Assisted Li...  (540) 682-7500
# 172                         Woods Cove Assisted Living  (540) 636-6611
# 173                                YAMA Services,  LLC  (804) 972-6842
# 174                                   Yama Services #2  (804) 789-0041
#
#                                          qualification
# 0    Non-AmbulatorySpecial Care UnitResidential and...
# 1                 Residential and Assisted Living Care
# 2    Ambulatory OnlyResidential and Assisted Living...
# 3    Residential and Assisted Living CareNon-Ambula...
# 4    Residential and Assisted Living CareSpecial Ca...
# ..                                                 ...
# 170  Special Care UnitResidential and Assisted Livi...
# 171  Residential and Assisted Living CareNon-Ambula...
# 172  Residential and Assisted Living CareSpecial Ca...
# 173  Residential and Assisted Living CareNon-Ambula...
# 174  Residential and Assisted Living CareNon-Ambula...
#
# [175 rows x 16 columns]

# %%
## convert float to int
loc['loc_id'] = loc['loc_id'].astype('int')

# %%
## Break out row for each inspection within facility
loc_insp = loc.explode('inspections').reset_index(drop=True)

## Following steps needed if dataframe came from csv. The Inspections field is no longer a list when reading in from csv
#from ast import literal_eval
#loc_insp['inspections'] = loc_insp['inspections'].apply(literal_eval)
#loc_insp = loc_insp.explode('inspections').reset_index(drop=True)

# %%
loc_insp
# Out:
#               _type                   address     administrator  \
# 0     location_info       1000 Twinridge Lane  Paige  Carpenter
# 1     location_info       1000 Twinridge Lane  Paige  Carpenter
# 2     location_info       1000 Twinridge Lane  Paige  Carpenter
# 3     location_info       1000 Twinridge Lane  Paige  Carpenter
# 4     location_info       1000 Twinridge Lane  Paige  Carpenter
# ...             ...                       ...               ...
# 1469  location_info        10046 Rinker Drive      Bill  Okyere
# 1470  location_info        10046 Rinker Drive      Bill  Okyere
# 1471  location_info        10046 Rinker Drive      Bill  Okyere
# 1472  location_info        10046 Rinker Drive      Bill  Okyere
# 1473  location_info  10192 Atlee Station Road      Bill  Okyere
#
#                  business_hours capacity                   city_zip  \
# 0     24 hours  - 24 hours, \r7      120        RICHMOND, VA  23235
# 1     24 hours  - 24 hours, \r7      120        RICHMOND, VA  23235
# 2     24 hours  - 24 hours, \r7      120        RICHMOND, VA  23235
# 3     24 hours  - 24 hours, \r7      120        RICHMOND, VA  23235
# 4     24 hours  - 24 hours, \r7      120        RICHMOND, VA  23235
# ...                         ...      ...                        ...
# 1469        24 hours , \r7 days        8  MECHANICSVILLE, VA  23116
# 1470        24 hours , \r7 days        8  MECHANICSVILLE, VA  23116
# 1471        24 hours , \r7 days        8  MECHANICSVILLE, VA  23116
# 1472        24 hours , \r7 days        8  MECHANICSVILLE, VA  23116
# 1473       8am  - 8am, \r7 days        8  MECHANICSVILLE, VA  23116
#
#      expiration_date             facility_type  loc_id  \
# 0      Aug. 27, 2023  Assisted Living Facility   44307
# 1      Aug. 27, 2023  Assisted Living Facility   44307
# 2      Aug. 27, 2023  Assisted Living Facility   44307
# 3      Aug. 27, 2023  Assisted Living Facility   44307
# 4      Aug. 27, 2023  Assisted Living Facility   44307
# ...              ...                       ...     ...
# 1469   Nov. 20, 2023  Assisted Living Facility   40095
# 1470   Nov. 20, 2023  Assisted Living Facility   40095
# 1471   Nov. 20, 2023  Assisted Living Facility   40095
# 1472   Nov. 20, 2023  Assisted Living Facility   40095
# 1473   Oct. 11, 2022  Assisted Living Facility   48075
#
#                                             inspections     inspector_name  \
# 0     {'_type': 'inspection_info', 'id': 30760, 'loc...  Yvonne  Randolph:
# 1     {'_type': 'inspection_info', 'id': 29987, 'loc...  Yvonne  Randolph:
# 2     {'_type': 'inspection_info', 'id': 29663, 'loc...  Yvonne  Randolph:
# 3     {'_type': 'inspection_info', 'id': 28727, 'loc...  Yvonne  Randolph:
# 4     {'_type': 'inspection_info', 'id': 27040, 'loc...  Yvonne  Randolph:
# ...                                                 ...                ...
# 1469  {'_type': 'inspection_info', 'id': 28123, 'loc...  Yvonne  Randolph:
# 1470  {'_type': 'inspection_info', 'id': 26421, 'loc...  Yvonne  Randolph:
# 1471  {'_type': 'inspection_info', 'id': 25600, 'loc...  Yvonne  Randolph:
# 1472  {'_type': 'inspection_info', 'id': 24151, 'loc...  Yvonne  Randolph:
# 1473  {'_type': 'inspection_info', 'id': 30581, 'loc...  Yvonne  Randolph:
#
#      inspector_phone license_type                 name    phone_number  \
# 0     (804) 662-7454     Two Year  Seaton Chesterfield  (804) 327-1990
# 1     (804) 662-7454     Two Year  Seaton Chesterfield  (804) 327-1990
# 2     (804) 662-7454     Two Year  Seaton Chesterfield  (804) 327-1990
# 3     (804) 662-7454     Two Year  Seaton Chesterfield  (804) 327-1990
# 4     (804) 662-7454     Two Year  Seaton Chesterfield  (804) 327-1990
# ...              ...          ...                  ...             ...
# 1469  (804) 662-7454   Three Year  YAMA Services,  LLC  (804) 972-6842
# 1470  (804) 662-7454   Three Year  YAMA Services,  LLC  (804) 972-6842
# 1471  (804) 662-7454   Three Year  YAMA Services,  LLC  (804) 972-6842
# 1472  (804) 662-7454   Three Year  YAMA Services,  LLC  (804) 972-6842
# 1473  (804) 662-7454  Conditional     Yama Services #2  (804) 789-0041
#
#                                           qualification
# 0     Non-AmbulatorySpecial Care UnitResidential and...
# 1     Non-AmbulatorySpecial Care UnitResidential and...
# 2     Non-AmbulatorySpecial Care UnitResidential and...
# 3     Non-AmbulatorySpecial Care UnitResidential and...
# 4     Non-AmbulatorySpecial Care UnitResidential and...
# ...                                                 ...
# 1469  Residential and Assisted Living CareNon-Ambula...
# 1470  Residential and Assisted Living CareNon-Ambula...
# 1471  Residential and Assisted Living CareNon-Ambula...
# 1472  Residential and Assisted Living CareNon-Ambula...
# 1473  Residential and Assisted Living CareNon-Ambula...
#
# [1474 rows x 16 columns]

# %%
## break out inspection column on its own to expand table to merge back to loc table
insp = loc_insp['inspections']
insp
# Out:
# 0       {'_type': 'inspection_info', 'id': 30760, 'loc...
# 1       {'_type': 'inspection_info', 'id': 29987, 'loc...
# 2       {'_type': 'inspection_info', 'id': 29663, 'loc...
# 3       {'_type': 'inspection_info', 'id': 28727, 'loc...
# 4       {'_type': 'inspection_info', 'id': 27040, 'loc...
#                               ...
# 1469    {'_type': 'inspection_info', 'id': 28123, 'loc...
# 1470    {'_type': 'inspection_info', 'id': 26421, 'loc...
# 1471    {'_type': 'inspection_info', 'id': 25600, 'loc...
# 1472    {'_type': 'inspection_info', 'id': 24151, 'loc...
# 1473    {'_type': 'inspection_info', 'id': 30581, 'loc...
# Name: inspections, Length: 1474, dtype: object

# %%
insp = insp.apply(pd.Series)

# %%
insp
# Out:
#                 _type     id  loc_id            date complaint  \
# 0     inspection_info  30760   44307    June 6, 2022
# 1     inspection_info  29987   44307    Nov. 5, 2021        No
# 2     inspection_info  29663   44307   July 28, 2021        No
# 3     inspection_info  28727   44307   Nov. 18, 2020        No
# 4     inspection_info  27040   44307   July 25, 2019        No
# ...               ...    ...     ...             ...       ...
# 1469  inspection_info  28123   40095    May 29, 2020        No
# 1470  inspection_info  26421   40095  March 25, 2019        No
# 1471  inspection_info  25600   40095   Aug. 28, 2018        No
# 1472  inspection_info  24151   40095   Aug. 15, 2017        No
# 1473  inspection_info  30581   48075  April 11, 2022        No
#
#                                          areas_reviewed  \
# 0         22VAC40-73 RESIDENT CARE AND RELATED SERVICES
# 1                                  22VAC40-73 PERSONNEL
# 2     22VAC40-73 ADMINISTRATION AND ADMINISTRATIVE S...
# 3                                  22VAC40-73 PERSONNEL
# 4     22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# ...                                                 ...
# 1469  22VAC40-73 ADMINISTRATION AND ADMINISTRATIVE S...
# 1470                    22VAC40-73 BUILDING AND GROUNDS
# 1471  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 1472  22VAC40-72 GENERAL PROVISIONS22VAC40-72 ADMINI...
# 1473  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
#
#                                                comments  \
# 0     A complaint was received by VDSS Division of L...
# 1     A report was received by the Department that t...
# 2     A renewal inspection was initiated on 7/23/202...
# 3     This inspection was conducted by licensing sta...
# 4     An unannounced renewal inspection was conducte...
# ...                                                 ...
# 1469  This inspection was conducted by licensing sta...
# 1470  An announced inspection was conducted at the f...
# 1471  An unannounced renewal inspection was conducte...
# 1472  An unannounced monitoring inspection was compl...
# 1473  An initial inspection was completed on 4/11/20...
#
#                                              violations technical_assistance
# 0                                                   NaN                  NaN
# 1     [{'standard_#': '22VAC40-73-150-B', 'descripti...                  NaN
# 2     [{'standard_#': '22VAC40-73-680-H', 'descripti...                  NaN
# 3     [{'standard_#': '22VAC40-73-110-1', 'descripti...                  NaN
# 4     [{'standard_#': '22VAC40-73-530-C', 'descripti...                  NaN
# ...                                                 ...                  ...
# 1469                                                NaN                  NaN
# 1470                                                NaN                  NaN
# 1471  [{'standard_#': '22VAC40-73-260-A', 'descripti...                  NaN
# 1472                                                NaN                  NaN
# 1473                                                NaN                  NaN
#
# [1474 rows x 9 columns]

# %%
insp_viol = insp.explode('violations').reset_index(drop=True)

# %%
insp_viol
# Out:
#                 _type     id  loc_id            date complaint  \
# 0     inspection_info  30760   44307    June 6, 2022
# 1     inspection_info  29987   44307    Nov. 5, 2021        No
# 2     inspection_info  29663   44307   July 28, 2021        No
# 3     inspection_info  28727   44307   Nov. 18, 2020        No
# 4     inspection_info  27040   44307   July 25, 2019        No
# ...               ...    ...     ...             ...       ...
# 4174  inspection_info  26421   40095  March 25, 2019        No
# 4175  inspection_info  25600   40095   Aug. 28, 2018        No
# 4176  inspection_info  25600   40095   Aug. 28, 2018        No
# 4177  inspection_info  24151   40095   Aug. 15, 2017        No
# 4178  inspection_info  30581   48075  April 11, 2022        No
#
#                                          areas_reviewed  \
# 0         22VAC40-73 RESIDENT CARE AND RELATED SERVICES
# 1                                  22VAC40-73 PERSONNEL
# 2     22VAC40-73 ADMINISTRATION AND ADMINISTRATIVE S...
# 3                                  22VAC40-73 PERSONNEL
# 4     22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# ...                                                 ...
# 4174                    22VAC40-73 BUILDING AND GROUNDS
# 4175  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 4176  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 4177  22VAC40-72 GENERAL PROVISIONS22VAC40-72 ADMINI...
# 4178  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
#
#                                                comments  \
# 0     A complaint was received by VDSS Division of L...
# 1     A report was received by the Department that t...
# 2     A renewal inspection was initiated on 7/23/202...
# 3     This inspection was conducted by licensing sta...
# 4     An unannounced renewal inspection was conducte...
# ...                                                 ...
# 4174  An announced inspection was conducted at the f...
# 4175  An unannounced renewal inspection was conducte...
# 4176  An unannounced renewal inspection was conducte...
# 4177  An unannounced monitoring inspection was compl...
# 4178  An initial inspection was completed on 4/11/20...
#
#                                              violations technical_assistance
# 0                                                   NaN                  NaN
# 1     {'standard_#': '22VAC40-73-150-B', 'descriptio...                  NaN
# 2     {'standard_#': '22VAC40-73-680-H', 'descriptio...                  NaN
# 3     {'standard_#': '22VAC40-73-110-1', 'descriptio...                  NaN
# 4     {'standard_#': '22VAC40-73-530-C', 'descriptio...                  NaN
# ...                                                 ...                  ...
# 4174                                                NaN                  NaN
# 4175  {'standard_#': '22VAC40-73-260-A', 'descriptio...                  NaN
# 4176  {'standard_#': '22VAC40-73-450-F', 'descriptio...                  NaN
# 4177                                                NaN                  NaN
# 4178                                                NaN                  NaN
#
# [4179 rows x 9 columns]

# %%
## break out violations column on its own to expand table to merge back to loc table
viol = insp_viol['violations']
viol = viol.apply(pd.Series)

# %%
viol
# Out:
#        0 complaint_related                                        description  \
# 0    NaN               NaN                                                NaN
# 1    NaN               NaN  Based on communications with former staff, it ...
# 2    NaN               NaN  Based on a review of the June 2021 Medication ...
# 3    NaN               NaN  Based on a review of fourteen criminal backgro...
# 4    NaN               NaN  Based on an inspection of the facility on 7/25...
# ...   ..               ...                                                ...
# 4174 NaN               NaN                                                NaN
# 4175 NaN               NaN  Based on a review of  three staff files on 8/2...
# 4176 NaN               NaN  Based on a review of 4 resident files, one ind...
# 4177 NaN               NaN                                                NaN
# 4178 NaN               NaN                                                NaN
#
#                                      plan_of_correction        standard_#
# 0                                                   NaN               NaN
# 1                                                   NaN  22VAC40-73-150-B
# 2                                                   NaN  22VAC40-73-680-H
# 3                                                   NaN  22VAC40-73-110-1
# 4     In-service held with all staff assigned to mem...  22VAC40-73-530-C
# ...                                                 ...               ...
# 4174                                                NaN               NaN
# 4175  Staff # 2 secured certification in first aid o...  22VAC40-73-260-A
# 4176                                                NaN  22VAC40-73-450-F
# 4177                                                NaN               NaN
# 4178                                                NaN               NaN
#
# [4179 rows x 5 columns]

# %%
## join violations back to inspections
insp_viol = insp_viol.join(viol)

# %%
insp_viol
# Out:
#                 _type     id  loc_id            date complaint  \
# 0     inspection_info  30760   44307    June 6, 2022
# 1     inspection_info  29987   44307    Nov. 5, 2021        No
# 2     inspection_info  29663   44307   July 28, 2021        No
# 3     inspection_info  28727   44307   Nov. 18, 2020        No
# 4     inspection_info  27040   44307   July 25, 2019        No
# ...               ...    ...     ...             ...       ...
# 4174  inspection_info  26421   40095  March 25, 2019        No
# 4175  inspection_info  25600   40095   Aug. 28, 2018        No
# 4176  inspection_info  25600   40095   Aug. 28, 2018        No
# 4177  inspection_info  24151   40095   Aug. 15, 2017        No
# 4178  inspection_info  30581   48075  April 11, 2022        No
#
#                                          areas_reviewed  \
# 0         22VAC40-73 RESIDENT CARE AND RELATED SERVICES
# 1                                  22VAC40-73 PERSONNEL
# 2     22VAC40-73 ADMINISTRATION AND ADMINISTRATIVE S...
# 3                                  22VAC40-73 PERSONNEL
# 4     22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# ...                                                 ...
# 4174                    22VAC40-73 BUILDING AND GROUNDS
# 4175  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 4176  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 4177  22VAC40-72 GENERAL PROVISIONS22VAC40-72 ADMINI...
# 4178  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
#
#                                                comments  \
# 0     A complaint was received by VDSS Division of L...
# 1     A report was received by the Department that t...
# 2     A renewal inspection was initiated on 7/23/202...
# 3     This inspection was conducted by licensing sta...
# 4     An unannounced renewal inspection was conducte...
# ...                                                 ...
# 4174  An announced inspection was conducted at the f...
# 4175  An unannounced renewal inspection was conducte...
# 4176  An unannounced renewal inspection was conducte...
# 4177  An unannounced monitoring inspection was compl...
# 4178  An initial inspection was completed on 4/11/20...
#
#                                              violations technical_assistance  \
# 0                                                   NaN                  NaN
# 1     {'standard_#': '22VAC40-73-150-B', 'descriptio...                  NaN
# 2     {'standard_#': '22VAC40-73-680-H', 'descriptio...                  NaN
# 3     {'standard_#': '22VAC40-73-110-1', 'descriptio...                  NaN
# 4     {'standard_#': '22VAC40-73-530-C', 'descriptio...                  NaN
# ...                                                 ...                  ...
# 4174                                                NaN                  NaN
# 4175  {'standard_#': '22VAC40-73-260-A', 'descriptio...                  NaN
# 4176  {'standard_#': '22VAC40-73-450-F', 'descriptio...                  NaN
# 4177                                                NaN                  NaN
# 4178                                                NaN                  NaN
#
#        0 complaint_related                                        description  \
# 0    NaN               NaN                                                NaN
# 1    NaN               NaN  Based on communications with former staff, it ...
# 2    NaN               NaN  Based on a review of the June 2021 Medication ...
# 3    NaN               NaN  Based on a review of fourteen criminal backgro...
# 4    NaN               NaN  Based on an inspection of the facility on 7/25...
# ...   ..               ...                                                ...
# 4174 NaN               NaN                                                NaN
# 4175 NaN               NaN  Based on a review of  three staff files on 8/2...
# 4176 NaN               NaN  Based on a review of 4 resident files, one ind...
# 4177 NaN               NaN                                                NaN
# 4178 NaN               NaN                                                NaN
#
#                                      plan_of_correction        standard_#
# 0                                                   NaN               NaN
# 1                                                   NaN  22VAC40-73-150-B
# 2                                                   NaN  22VAC40-73-680-H
# 3                                                   NaN  22VAC40-73-110-1
# 4     In-service held with all staff assigned to mem...  22VAC40-73-530-C
# ...                                                 ...               ...
# 4174                                                NaN               NaN
# 4175  Staff # 2 secured certification in first aid o...  22VAC40-73-260-A
# 4176                                                NaN  22VAC40-73-450-F
# 4177                                                NaN               NaN
# 4178                                                NaN               NaN
#
# [4179 rows x 14 columns]

# %%
insp_viol.drop(insp_viol.columns[[0,7,9]] , axis=1, inplace = True)
insp_viol
# Out:
#          id  loc_id            date complaint  \
# 0     30760   44307    June 6, 2022
# 1     29987   44307    Nov. 5, 2021        No
# 2     29663   44307   July 28, 2021        No
# 3     28727   44307   Nov. 18, 2020        No
# 4     27040   44307   July 25, 2019        No
# ...     ...     ...             ...       ...
# 4174  26421   40095  March 25, 2019        No
# 4175  25600   40095   Aug. 28, 2018        No
# 4176  25600   40095   Aug. 28, 2018        No
# 4177  24151   40095   Aug. 15, 2017        No
# 4178  30581   48075  April 11, 2022        No
#
#                                          areas_reviewed  \
# 0         22VAC40-73 RESIDENT CARE AND RELATED SERVICES
# 1                                  22VAC40-73 PERSONNEL
# 2     22VAC40-73 ADMINISTRATION AND ADMINISTRATIVE S...
# 3                                  22VAC40-73 PERSONNEL
# 4     22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# ...                                                 ...
# 4174                    22VAC40-73 BUILDING AND GROUNDS
# 4175  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 4176  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 4177  22VAC40-72 GENERAL PROVISIONS22VAC40-72 ADMINI...
# 4178  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
#
#                                                comments technical_assistance  \
# 0     A complaint was received by VDSS Division of L...                  NaN
# 1     A report was received by the Department that t...                  NaN
# 2     A renewal inspection was initiated on 7/23/202...                  NaN
# 3     This inspection was conducted by licensing sta...                  NaN
# 4     An unannounced renewal inspection was conducte...                  NaN
# ...                                                 ...                  ...
# 4174  An announced inspection was conducted at the f...                  NaN
# 4175  An unannounced renewal inspection was conducte...                  NaN
# 4176  An unannounced renewal inspection was conducte...                  NaN
# 4177  An unannounced monitoring inspection was compl...                  NaN
# 4178  An initial inspection was completed on 4/11/20...                  NaN
#
#      complaint_related                                        description  \
# 0                  NaN                                                NaN
# 1                  NaN  Based on communications with former staff, it ...
# 2                  NaN  Based on a review of the June 2021 Medication ...
# 3                  NaN  Based on a review of fourteen criminal backgro...
# 4                  NaN  Based on an inspection of the facility on 7/25...
# ...                ...                                                ...
# 4174               NaN                                                NaN
# 4175               NaN  Based on a review of  three staff files on 8/2...
# 4176               NaN  Based on a review of 4 resident files, one ind...
# 4177               NaN                                                NaN
# 4178               NaN                                                NaN
#
#                                      plan_of_correction        standard_#
# 0                                                   NaN               NaN
# 1                                                   NaN  22VAC40-73-150-B
# 2                                                   NaN  22VAC40-73-680-H
# 3                                                   NaN  22VAC40-73-110-1
# 4     In-service held with all staff assigned to mem...  22VAC40-73-530-C
# ...                                                 ...               ...
# 4174                                                NaN               NaN
# 4175  Staff # 2 secured certification in first aid o...  22VAC40-73-260-A
# 4176                                                NaN  22VAC40-73-450-F
# 4177                                                NaN               NaN
# 4178                                                NaN               NaN
#
# [4179 rows x 11 columns]

# %%
## merge inspection table back to loc table
final = loc.merge(insp_viol, on='loc_id', how='left')

# %%
final
# Out:
#               _type                   address     administrator  \
# 0     location_info       1000 Twinridge Lane  Paige  Carpenter
# 1     location_info       1000 Twinridge Lane  Paige  Carpenter
# 2     location_info       1000 Twinridge Lane  Paige  Carpenter
# 3     location_info       1000 Twinridge Lane  Paige  Carpenter
# 4     location_info       1000 Twinridge Lane  Paige  Carpenter
# ...             ...                       ...               ...
# 4280  location_info        10046 Rinker Drive      Bill  Okyere
# 4281  location_info        10046 Rinker Drive      Bill  Okyere
# 4282  location_info        10046 Rinker Drive      Bill  Okyere
# 4283  location_info        10046 Rinker Drive      Bill  Okyere
# 4284  location_info  10192 Atlee Station Road      Bill  Okyere
#
#                  business_hours capacity                   city_zip  \
# 0     24 hours  - 24 hours, \r7      120        RICHMOND, VA  23235
# 1     24 hours  - 24 hours, \r7      120        RICHMOND, VA  23235
# 2     24 hours  - 24 hours, \r7      120        RICHMOND, VA  23235
# 3     24 hours  - 24 hours, \r7      120        RICHMOND, VA  23235
# 4     24 hours  - 24 hours, \r7      120        RICHMOND, VA  23235
# ...                         ...      ...                        ...
# 4280        24 hours , \r7 days        8  MECHANICSVILLE, VA  23116
# 4281        24 hours , \r7 days        8  MECHANICSVILLE, VA  23116
# 4282        24 hours , \r7 days        8  MECHANICSVILLE, VA  23116
# 4283        24 hours , \r7 days        8  MECHANICSVILLE, VA  23116
# 4284       8am  - 8am, \r7 days        8  MECHANICSVILLE, VA  23116
#
#      expiration_date             facility_type  loc_id  \
# 0      Aug. 27, 2023  Assisted Living Facility   44307
# 1      Aug. 27, 2023  Assisted Living Facility   44307
# 2      Aug. 27, 2023  Assisted Living Facility   44307
# 3      Aug. 27, 2023  Assisted Living Facility   44307
# 4      Aug. 27, 2023  Assisted Living Facility   44307
# ...              ...                       ...     ...
# 4280   Nov. 20, 2023  Assisted Living Facility   40095
# 4281   Nov. 20, 2023  Assisted Living Facility   40095
# 4282   Nov. 20, 2023  Assisted Living Facility   40095
# 4283   Nov. 20, 2023  Assisted Living Facility   40095
# 4284   Oct. 11, 2022  Assisted Living Facility   48075
#
#                                             inspections  ...     id  \
# 0     [{'_type': 'inspection_info', 'id': 30760, 'lo...  ...  30760
# 1     [{'_type': 'inspection_info', 'id': 30760, 'lo...  ...  29987
# 2     [{'_type': 'inspection_info', 'id': 30760, 'lo...  ...  29663
# 3     [{'_type': 'inspection_info', 'id': 30760, 'lo...  ...  28727
# 4     [{'_type': 'inspection_info', 'id': 30760, 'lo...  ...  27040
# ...                                                 ...  ...    ...
# 4280  [{'_type': 'inspection_info', 'id': 28551, 'lo...  ...  26421
# 4281  [{'_type': 'inspection_info', 'id': 28551, 'lo...  ...  25600
# 4282  [{'_type': 'inspection_info', 'id': 28551, 'lo...  ...  25600
# 4283  [{'_type': 'inspection_info', 'id': 28551, 'lo...  ...  24151
# 4284  [{'_type': 'inspection_info', 'id': 30581, 'lo...  ...  30581
#
#                 date complaint  \
# 0       June 6, 2022
# 1       Nov. 5, 2021        No
# 2      July 28, 2021        No
# 3      Nov. 18, 2020        No
# 4      July 25, 2019        No
# ...              ...       ...
# 4280  March 25, 2019        No
# 4281   Aug. 28, 2018        No
# 4282   Aug. 28, 2018        No
# 4283   Aug. 15, 2017        No
# 4284  April 11, 2022        No
#
#                                          areas_reviewed  \
# 0         22VAC40-73 RESIDENT CARE AND RELATED SERVICES
# 1                                  22VAC40-73 PERSONNEL
# 2     22VAC40-73 ADMINISTRATION AND ADMINISTRATIVE S...
# 3                                  22VAC40-73 PERSONNEL
# 4     22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# ...                                                 ...
# 4280                    22VAC40-73 BUILDING AND GROUNDS
# 4281  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 4282  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 4283  22VAC40-72 GENERAL PROVISIONS22VAC40-72 ADMINI...
# 4284  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
#
#                                                comments technical_assistance  \
# 0     A complaint was received by VDSS Division of L...                  NaN
# 1     A report was received by the Department that t...                  NaN
# 2     A renewal inspection was initiated on 7/23/202...                  NaN
# 3     This inspection was conducted by licensing sta...                  NaN
# 4     An unannounced renewal inspection was conducte...                  NaN
# ...                                                 ...                  ...
# 4280  An announced inspection was conducted at the f...                  NaN
# 4281  An unannounced renewal inspection was conducte...                  NaN
# 4282  An unannounced renewal inspection was conducte...                  NaN
# 4283  An unannounced monitoring inspection was compl...                  NaN
# 4284  An initial inspection was completed on 4/11/20...                  NaN
#
#       complaint_related                                        description  \
# 0                   NaN                                                NaN
# 1                   NaN  Based on communications with former staff, it ...
# 2                   NaN  Based on a review of the June 2021 Medication ...
# 3                   NaN  Based on a review of fourteen criminal backgro...
# 4                   NaN  Based on an inspection of the facility on 7/25...
# ...                 ...                                                ...
# 4280                NaN                                                NaN
# 4281                NaN  Based on a review of  three staff files on 8/2...
# 4282                NaN  Based on a review of 4 resident files, one ind...
# 4283                NaN                                                NaN
# 4284                NaN                                                NaN
#
#                                      plan_of_correction        standard_#
# 0                                                   NaN               NaN
# 1                                                   NaN  22VAC40-73-150-B
# 2                                                   NaN  22VAC40-73-680-H
# 3                                                   NaN  22VAC40-73-110-1
# 4     In-service held with all staff assigned to mem...  22VAC40-73-530-C
# ...                                                 ...               ...
# 4280                                                NaN               NaN
# 4281  Staff # 2 secured certification in first aid o...  22VAC40-73-260-A
# 4282                                                NaN  22VAC40-73-450-F
# 4283                                                NaN               NaN
# 4284                                                NaN               NaN
#
# [4285 rows x 26 columns]

# %%
final.drop(final.columns[[0,9]], axis=1, inplace = True)

# %%
#final.to_csv('final500.csv',index=False)

# %%
#import os
#import glob

#extension = 'csv'
#all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

##combine all files in the list
#final_combined = pd.concat([pd.read_csv(f) for f in all_filenames ])

#final_combined
# Out:
#                        address   administrator        business_hours  \
# 0         31 Stoney Point Road  Mr. Cody  Pike   24 hours , \r7 days
# 1         31 Stoney Point Road  Mr. Cody  Pike   24 hours , \r7 days
# 2         31 Stoney Point Road  Mr. Cody  Pike   24 hours , \r7 days
# 3         31 Stoney Point Road  Mr. Cody  Pike   24 hours , \r7 days
# 4         31 Stoney Point Road  Mr. Cody  Pike   24 hours , \r7 days
# ...                        ...             ...                   ...
# 4280        10046 Rinker Drive    Bill  Okyere   24 hours , \r7 days
# 4281        10046 Rinker Drive    Bill  Okyere   24 hours , \r7 days
# 4282        10046 Rinker Drive    Bill  Okyere   24 hours , \r7 days
# 4283        10046 Rinker Drive    Bill  Okyere   24 hours , \r7 days
# 4284  10192 Atlee Station Road    Bill  Okyere  8am  - 8am, \r7 days
#
#       capacity                   city_zip expiration_date  \
# 0           19      CUMBERLAND, VA  23040  March 16, 2022
# 1           19      CUMBERLAND, VA  23040  March 16, 2022
# 2           19      CUMBERLAND, VA  23040  March 16, 2022
# 3           19      CUMBERLAND, VA  23040  March 16, 2022
# 4           19      CUMBERLAND, VA  23040  March 16, 2022
# ...        ...                        ...             ...
# 4280         8  MECHANICSVILLE, VA  23116   Nov. 20, 2023
# 4281         8  MECHANICSVILLE, VA  23116   Nov. 20, 2023
# 4282         8  MECHANICSVILLE, VA  23116   Nov. 20, 2023
# 4283         8  MECHANICSVILLE, VA  23116   Nov. 20, 2023
# 4284         8  MECHANICSVILLE, VA  23116   Oct. 11, 2022
#
#                  facility_type  loc_id     inspector_name inspector_phone  \
# 0     Assisted Living Facility    8364   Kimberly  Davis:  (804) 662-7578
# 1     Assisted Living Facility    8364   Kimberly  Davis:  (804) 662-7578
# 2     Assisted Living Facility    8364   Kimberly  Davis:  (804) 662-7578
# 3     Assisted Living Facility    8364   Kimberly  Davis:  (804) 662-7578
# 4     Assisted Living Facility    8364   Kimberly  Davis:  (804) 662-7578
# ...                        ...     ...                ...             ...
# 4280  Assisted Living Facility   40095  Yvonne  Randolph:  (804) 662-7454
# 4281  Assisted Living Facility   40095  Yvonne  Randolph:  (804) 662-7454
# 4282  Assisted Living Facility   40095  Yvonne  Randolph:  (804) 662-7454
# 4283  Assisted Living Facility   40095  Yvonne  Randolph:  (804) 662-7454
# 4284  Assisted Living Facility   48075  Yvonne  Randolph:  (804) 662-7454
#
#       ...     id            date complaint  \
# 0     ...  29026   Feb. 26, 2021        No
# 1     ...  27827   Feb. 28, 2020        No
# 2     ...  27827   Feb. 28, 2020        No
# 3     ...  27827   Feb. 28, 2020        No
# 4     ...  27827   Feb. 28, 2020        No
# ...   ...    ...             ...       ...
# 4280  ...  26421  March 25, 2019        No
# 4281  ...  25600   Aug. 28, 2018        No
# 4282  ...  25600   Aug. 28, 2018        No
# 4283  ...  24151   Aug. 15, 2017        No
# 4284  ...  30581  April 11, 2022        No
#
#                                          areas_reviewed  \
# 0     22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 1     22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 2     22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 3     22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 4     22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# ...                                                 ...
# 4280                    22VAC40-73 BUILDING AND GROUNDS
# 4281  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 4282  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
# 4283  22VAC40-72 GENERAL PROVISIONS22VAC40-72 ADMINI...
# 4284  22VAC40-73 GENERAL PROVISIONS22VAC40-73 ADMINI...
#
#                                                comments technical_assistance  \
# 0     This inspection was conducted by licensing sta...                  NaN
# 1     An unannounced renewal inspection was conducte...                  NaN
# 2     An unannounced renewal inspection was conducte...                  NaN
# 3     An unannounced renewal inspection was conducte...                  NaN
# 4     An unannounced renewal inspection was conducte...                  NaN
# ...                                                 ...                  ...
# 4280  An announced inspection was conducted at the f...                  NaN
# 4281  An unannounced renewal inspection was conducte...                  NaN
# 4282  An unannounced renewal inspection was conducte...                  NaN
# 4283  An unannounced monitoring inspection was compl...                  NaN
# 4284  An initial inspection was completed on 4/11/20...                  NaN
#
#      complaint_related                                        description  \
# 0                  NaN  Based on a review of resident records, the fac...
# 1                  NaN  Based on a review of staff records, the facili...
# 2                  NaN  Based on a review of facility documentation, t...
# 3                  NaN  Based on a review of the facility's first aid ...
# 4                  NaN  Based on a review of facility documentation, t...
# ...                ...                                                ...
# 4280               NaN                                                NaN
# 4281               NaN  Based on a review of  three staff files on 8/2...
# 4282               NaN  Based on a review of 4 resident files, one ind...
# 4283               NaN                                                NaN
# 4284               NaN                                                NaN
#
#                                      plan_of_correction        standard_#
# 0                                                   NaN  22VAC40-73-450-C
# 1     Going forward staff training hours will be cle...  22VAC40-73-210-A
# 2     Emergency preparedness will be rewritten and w...  22VAC40-73-950-E
# 3     The expired Neosporin has been thrown away and...  22VAC40-73-980-A
# 4                                                   NaN  22VAC40-73-990-C
# ...                                                 ...               ...
# 4280                                                NaN               NaN
# 4281  Staff # 2 secured certification in first aid o...  22VAC40-73-260-A
# 4282                                                NaN  22VAC40-73-450-F
# 4283                                                NaN               NaN
# 4284                                                NaN               NaN
#
# [16383 rows x 24 columns]

# %%
final_combined.to_excel('final.xlsx',index=False)

# %%
#del ids_
ids_ = pd.DataFrame(data= ids, columns= ['ids'])
#ids_ = ids
ids_
ids_.to_csv('ids.csv',index=False)

# %%
li = list(loc.id.value_counts())
len(li)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-d2c257a3c1b2> in <module>
# ----> 1 li = list(loc.id.value_counts())
#       2 len(li)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'id'

# %%
final_combined.to_csv('dss.csv',index=False)
